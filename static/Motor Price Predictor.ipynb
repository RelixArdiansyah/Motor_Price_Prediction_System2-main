# %%
import pandas as pd
import numpy as np

# %%
motor = pd.read_csv ('olx.csv')

# %%
motor.head()
# Out:
#     company       name  year kms_driven       Price fuel_type
# 0    Yamaha       NMAX  2018   5000 kms  21.000.000    bensin
# 1     Honda      Vario  2014   5000 kms  10.500.000    bensin
# 2  Kawasaki  Ninja KRR  2012  30000 kms  25.000.000    bensin
# 3     Honda      Supra  2002   5000 kms   3.200.000    bensin
# 4     Honda      Vario  2022  25000 kms  19.950.000    bensin

# %%
motor.shape
# Out:
# (925, 6)

# %%
motor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 925 entries, 0 to 924
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   company     925 non-null    object
#  1   name        925 non-null    object
#  2   year        925 non-null    int64
#  3   kms_driven  925 non-null    object
#  4   Price       925 non-null    object
#  5   fuel_type   925 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 43.5+ KB

# %%
motor['year'].unique()
# Out:
# array([2018, 2014, 2012, 2002, 2022, 2023, 2015, 2011, 2021, 2020, 2016,
#        2010, 2005, 2017, 2019, 2007, 2013, 2009, 2006, 1991, 2004, 2008,
#        1996, 1986, 1999, 1995, 2024, 2001, 1997], dtype=int64)

# %%
motor['Price'].unique()
# Out:
# array(['21.000.000', '10.500.000', '25.000.000', '3.200.000',
#        '19.950.000', '18.000.000', '12.400.000', '7.500.000',
#        '15.300.000', '13.300.000', '15.000.000', '195.000.000',
#        '49.900.000', '635.000.000', '18.500.000', '15.500.000',
#        '16.700.000', '32.900.000', '29.800.000', '14.500.000',
#        '21.500.000', '16.800.000', '8.950.000', '20.750.000',
#        '520.000.000', '4.200.000', '19.250.000', '3.500.000',
#        '20.800.000', '13.500.000', '14.900.000', '16.400.000',
#        '25.500.000', '24.500.000', '5.750.000', '17.500.000',
#        '19.500.000', '5.850.000', '7.800.000', '12.500.000', '11.000.000',
#        '13.250.000', '10.350.000', '18.600.000', '16.250.000',
#        '11.500.000', '12.900.000', '8.500.000', '39.500.000',
#        '99.500.000', '53.000.000', '365.000.000', '45.000.000',
#        '51.000.000', '12.000.000', '8.550.000', '6.500.000', '13.900.000',
#        '15.200.000', '22.700.000', '16.900.000', '29.700.000',
# ...

# %%
motor['kms_driven'].unique()
# Out:
# array(['5000 kms', '30000 kms', '25000 kms', '20000 kms', '45000 kms',
#        '10000 kms', '50000 kms', '40000 kms', '15000 kms', '7000 kms',
#        '6000 kms', '65000 kms', '35000 kms', '55000 kms', '60000 kms',
#        '300000 kms', '75000 kms', '90000 kms', '95000 kms', '70000 kms',
#        '105000 kms', '80000 kms', '85000 kms', '100000 kms', '115000 kms',
#        '120000 kms'], dtype=object)

# %%
motor['fuel_type'].unique()
# Out:
# array(['bensin', 'listrik'], dtype=object)

# %%
motor['name'].unique()
# Out:
# array(['NMAX', 'Vario', 'Ninja KRR', 'Supra', 'Scoopy', 'Beat', 'Mio',
#        'GTS', 'Sprint', 'Touring', 'CBR', 'Ninja 250', 'Lexi', 'Vixion',
#        'Karya', 'R NineT', 'Vega R', 'PCX', 'Fino', '150', 'Xeon', 'ZX',
#        'Primavera', 'Softail', 'Xmax', 'Jupiter', 'Mega pro', 'CB 150R',
#        'Aerox', 'Freego', 'Soul GT', 'Forza', 'CB', 'YZF R15', 'BN',
#        'Sonic', 'MT 25', 'W800', 'Satria', 'GSX', 'Xabre', 'Shooter',
#        'Shogun', 'Byson', 'Astrea', 'kharisma', 'NSR', 'D-Tracker',
#        'Grizzly', 'Scorpio', 'Ninja R', 'Versys', 'Street', 'R1200GS',
#        'Monster 696', 'Duke', 'Vespa', 'Z Series', 'Estrella', 'F 1 ZR',
#        'R1', 'Ninja', 'Lain-lain', 'Patagonian Eagle', 'V-Rod', 'KLX',
#        'Impressa', 'RX', 'Tiger', 'CRF250Rally', 'Sportster', 'YZF R25',
#        'LX', 'WR 250', 'Ninja ER-6N', 'Revo', 'RC', 'Fazer', 'S 1000',
#        'RS Sport', 'Diavel Carbon', 'Panigale', 'Monkey', 'Little Cub',
# ...

# %%
backup = motor.copy()

# %%
motor['year'] = motor['year'].astype(int)

# %%
motor['year']
# Out:
# 0      2018
# 1      2014
# 2      2012
# 3      2002
# 4      2022
#        ...
# 920    2022
# 921    2020
# 922    2023
# 923    2022
# 924    2023
# Name: year, Length: 925, dtype: int32

# %%
# Ganti titik dengan koma, hapus pemisah ribuan, dan konversi kolom 'Price' menjadi integer
motor['Price'] = motor['Price'].str.replace('.', '', regex=False)  # Menghapus titik
motor['Price'] = motor['Price'].str.replace(',', '', regex=False)  # Menghapus koma (jika ada)
motor['Price'] = motor['Price'].astype(int)

# %%
motor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 925 entries, 0 to 924
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   company     925 non-null    object
#  1   name        925 non-null    object
#  2   year        925 non-null    int32
#  3   kms_driven  925 non-null    object
#  4   Price       925 non-null    int32
#  5   fuel_type   925 non-null    object
# dtypes: int32(2), object(4)
# memory usage: 36.3+ KB

# %%
motor['kms_driven'] = motor['kms_driven'].str.split(" ").str.get(0).str.replace(',','')

# %%
motor= motor[motor['kms_driven'].str.isnumeric()]

# %%
motor['kms_driven'] = motor['kms_driven'].astype(int)

# %%
motor.describe()
# Out:
#               year     kms_driven         Price
# count   925.000000     925.000000  9.250000e+02
# mean   2018.242162   20262.702703  4.284957e+07
# std       5.961979   28667.204576  9.963241e+07
# min    1986.000000    5000.000000  5.000000e+05
# 25%    2016.000000    5000.000000  1.130000e+07
# 50%    2020.000000   15000.000000  1.750000e+07
# 75%    2022.000000   25000.000000  2.750000e+07
# max    2024.000000  300000.000000  7.250000e+08

# %%
backup = motor.copy()

# %%
# Filter dan konversi kolom 'year'
motor['year'] = motor['year'].astype(str)
motor = motor[motor['year'].str.isnumeric()]
motor['year'] = motor['year'].astype(int)

# %%
# Hapus baris dengan 'Ask For Price' di kolom 'Price'
motor = motor[motor['Price'] != "Ask For Price"]

# %%
# Hapus baris dengan nilai missing di kolom 'fuel_type'
motor = motor[~motor['fuel_type'].isna()]

# %%
# Proses kolom 'name'
motor['name'] = motor['name'].str.split(' ').str.slice(0, 3).str.join(' ')

# %%
# Reset indeks
motor = motor.reset_index(drop=True)

# %%
(motor.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 925 entries, 0 to 924
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   company     925 non-null    object
#  1   name        925 non-null    object
#  2   year        925 non-null    int32
#  3   kms_driven  925 non-null    int32
#  4   Price       925 non-null    int32
#  5   fuel_type   925 non-null    object
# dtypes: int32(3), object(3)
# memory usage: 32.6+ KB

# %%
motor.to_csv('olx123.csv')

# %%
import seaborn as sns

# %%
sns.pairplot(motor)

# %%
ax=sns.relplot(x='company',y='Price',data=motor,hue='fuel_type',size='year',height=7,aspect=2)
ax.set_xticklabels(rotation=40,ha='right')

# %%
#MODEL
X = motor.drop(columns = 'Price')
y = motor['Price']

# %%
X
# Out:
#       company       name  year  kms_driven fuel_type
# 0      Yamaha       NMAX  2018        5000    bensin
# 1       Honda      Vario  2014        5000    bensin
# 2    Kawasaki  Ninja KRR  2012       30000    bensin
# 3       Honda      Supra  2002        5000    bensin
# 4       Honda      Vario  2022       25000    bensin
# ..        ...        ...   ...         ...       ...
# 920     Smoot  Lain-lain  2022       10000   listrik
# 921     Smoot  Lain-lain  2020        5000   listrik
# 922     Smoot  Lain-lain  2023        5000   listrik
# 923     Smoot  Lain-lain  2022        5000   listrik
# 924     Smoot  Lain-lain  2023        5000   listrik
#
# [925 rows x 5 columns]

# %%
y
# Out:
# 0      21000000
# 1      10500000
# 2      25000000
# 3       3200000
# 4      19950000
#          ...
# 920     9500000
# 921     2500000
# 922    10300000
# 923     8500000
# 924     3000000
# Name: Price, Length: 925, dtype: int32

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =train_test_split(X,y, test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
ohe = OneHotEncoder()
ohe.fit(X[['name', 'company','fuel_type']])
# Out:
# OneHotEncoder()

# %%
col_trans = make_column_transformer((OneHotEncoder(categories = ohe.categories_),['name', 'company','fuel_type']),remainder = 'passthrough')

# %%
lr = LinearRegression()

# %%
pipe = make_pipeline(col_trans,lr)

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['150', 'Aerox', 'Aprilia SR', 'Astrea', 'BN', 'Beat', 'Byson',
#        'CB', 'CB 150R', 'CBR', 'CRF250Rally', 'D-Tracker',
#        'Diavel Carbon', 'Duke', 'Estrella', 'F 1 ZR', 'Fazer', 'Fino',
#        'Forza', 'Freego', 'GSX', 'GTS', 'Grizzly', 'Impressa', '...
#                                                                             array(['Agats', 'Alva', 'Aprilia', 'BMW', 'Benelli', 'Ducati', 'Exsotik',
#        'Genio', 'Gesits', 'Goda', 'Harley Davidson', 'Honda', 'KTM',
#        'Kawasaki', 'Lain-lain', 'Piaggio', 'Selis', 'Smoot', 'Suzuki',
#        'Tangkas', 'United', 'Uwinifly', 'Vespa', 'Viar', 'Volta', 'Voxa',
#        'Winifly', 'Yadea', 'Yamaha'], dtype=object),
# ...

# %%
y_pred = pipe.predict(X_test)

# %%
y_pred
# Out:
# array([ 1.82131231e+07,  2.79736918e+07,  8.57161818e+06,  9.83372847e+06,
#         3.36025796e+07,  1.80137092e+07,  3.30915006e+07,  1.89833928e+07,
#         8.86557441e+06,  2.62114322e+07,  9.36319469e+07,  1.73191541e+07,
#         1.44150404e+07,  9.83372847e+06,  1.59319317e+07,  2.57105990e+07,
#         2.31331549e+07,  2.30416070e+07,  1.19002183e+07,  2.17940159e+07,
#         4.84072470e+07,  8.57161818e+06,  1.45384530e+07,  2.52953876e+07,
#         1.44150404e+07,  1.64703909e+07,  1.22903712e+07,  3.30915006e+07,
#         1.90938689e+07,  1.09673843e+08,  3.51160934e+06,  1.96081353e+07,
#         1.11349165e+08,  1.77465657e+07,  2.17808910e+07,  2.26682712e+07,
#         1.56781601e+07,  1.04736400e+08,  2.29362813e+07,  3.67616684e+07,
#         9.13689000e+06,  1.99038626e+07,  2.40421329e+08,  7.60930842e+06,
#         2.56478871e+06,  2.43590107e+07,  1.32864804e+08,  2.48985895e+07,
# ...

# %%
r2_score(y_test, y_pred)
# Out:
# 0.7038603039922551

# %%
scores =[]
for i in range(1000):
    X_train, X_test, y_train, y_test =train_test_split(X,y, test_size = 0.2, random_state = i)
    lr = LinearRegression()
    pipe = make_pipeline(col_trans,lr)
    pipe.fit(X_train, y_train)
    y_pred = pipe.predict(X_test)
    scores.append(r2_score(y_test, y_pred))

# %%
np.argmax(scores)
# Out:
# 345

# %%
scores[np.argmax(scores)]
# Out:
# 0.8972989998425182

# %%
X_train, X_test, y_train, y_test =train_test_split(X,y, test_size = 0.2, random_state = np.argmax(scores))
lr = LinearRegression()
pipe = make_pipeline(col_trans,lr)
pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# 0.8972989998425182

# %%
import pickle

# %%
pickle.dump(pipe,open('MotorPriceModel.pkl','wb'))

# %%
pipe.predict(pd.DataFrame([['Suzuki','Shogun','2002','105000','bensin']], columns =['company','name','year','kms_driven','fuel_type']))
# Out:
# array([19014749.51602888])

# %%
# !pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 1.4.1.post1
# Summary: A set of python modules for machine learning and data mining
# Home-page: https://scikit-learn.org
# Author:
# Author-email:
# License: new BSD
# Location: D:\Python312\Lib\site-packages
# Requires: joblib, numpy, scipy, threadpoolctl
# Required-by:
